# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAbdallah142/Pattern-Recognition/blob/main/assignment_3_2newpr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# !pip install tensorflow-io
import os
import tarfile
import librosa
import scipy.io
import scipy as sc
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import opendatasets as od
import tensorflow_io as tfio
import IPython.display as ipd
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
import sklearn.metrics as metrics
from glob import glob
from numpy import linalg
from os import listdir
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#----------------------------------------------------
from tensorflow.keras.regularizers import l1_l2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import compute_class_weight
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.7/dist-packages (0.1.22)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: tensorflow-io in /usr/local/lib/python3.7/dist-packages (0.26.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-io) (0.26.0)

# %%
od.download("https://www.kaggle.com/dmitrybabko/speech-emotion-recognition-en")
# Out:
# Skipping, found downloaded files in "./speech-emotion-recognition-en" (use force=True to force download)

# %%
def LoadAudio(dir_path):
    emotions = []
    data=[]

    for audio in os.listdir(dir_path):
        path = dir_path + audio
        temp , sr = librosa.load(path,sr=16000)
        wav, index = librosa.effects.trim(temp, top_db=60)       
        

        if len(wav) > (3*16000):
            wav = wav[:3*16000]
        else:
            padding = (3*16000) - len(wav)
            offset = padding // 2
            wav = np.pad(wav, (offset,3*16000- len(wav) - offset), 'constant') 

        mean = np.mean(wav)
        std = np.std(wav)
        out = np.ones( (len(wav)) ) 
        wav= np.divide((wav - mean),std,out=out, where=std!=0)#normalization & standarization
        
        data.append(wav)
        
        emotion = path.split('_')
        if emotion[2] == 'SAD':
            emotions.append(0)
        elif emotion[2] == 'ANG':
            emotions.append(1)
        elif emotion[2] == 'DIS':
            emotions.append(2)
        elif emotion[2] == 'NEU':
            emotions.append(3)
        elif emotion[2] == 'HAP':
            emotions.append(4)
        elif emotion[2] == 'FEA':
            emotions.append(5)
        else:
            emotions.append(6)
            
    return data,emotions

# %%
data,Labels =  LoadAudio('./speech-emotion-recognition-en/Crema/')

print(len(data))
print(len(Labels))
# Out:
# 7442
# 7442

# %%
train_data, test_data, train_labels, test_labels = train_test_split(data,Labels, test_size=0.30, random_state=42)
train_data,val_data, train_labels, val_labels = train_test_split(train_data,train_labels, test_size=0.05, random_state=42)
del(data)
del(Labels)
print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 4948
# 261
# 2233

# %%
train_size = len(train_data)
def shifting(data):
    shift = int(np.random.uniform(low=-5, high = 5)*1000)
    direction = np.random.randint(0, 2)
    if direction == 1:
        shift = -shift
    augmented_data = np.roll(data, shift)
    # Set to silence for heading/ tailing
    if shift > 0:
        augmented_data[:shift] = 0
    else:
        augmented_data[shift:] = 0
    return augmented_data

# %%
for i in range(train_size):
    shift_data = shifting(train_data[i])
    train_data.append(shift_data)
    train_labels.append(train_labels[i])

# %%
print(len(train_data))
print(len(train_labels))
# Out:
# 9896
# 9896

# %%
def mel_spectrogram_features(data):   
    temp = librosa.feature.melspectrogram(y=data, sr=16000, n_mels=128)
    mel_spec_db=librosa.power_to_db(temp, ref=np.max)
    return mel_spec_db

# %%
def extract_mel_spectrogram_features(data):
    set_spectorgram = np.zeros((len(data),128,94)) 
    for i in range(len(data)):
          set_spectorgram[i]= mel_spectrogram_features(data[i])
    return set_spectorgram

# %%
train_data = extract_mel_spectrogram_features(train_data)
val_data   = extract_mel_spectrogram_features(val_data)
test_data  = extract_mel_spectrogram_features(test_data)

# %%
def specAug(data,label):
  dataSize = len(data)
  for i in range(dataSize):
    data = np.append(data,[tfio.audio.freq_mask(data[i], param=10)],axis=0)
    label.append(label[i])
    data = np.append(data,[tfio.audio.time_mask(data[i], param=10)],axis=0)
    label.append(label[i])
  return data
train_data = specAug(train_data,train_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-fce1075e5ac2> in <module>()
#       7     label.append(label[i])
#       8   return data
# ----> 9 train_set_spectorgram = specAug(train_set_spectorgram,train_labels)
#
# <ipython-input-14-fce1075e5ac2> in specAug(data, label)
#       4     data = np.append(data,[tfio.audio.freq_mask(data[i], param=10)],axis=0)
#       5     label.append(label[i])
# ----> 6     data = np.append(data,[tfio.audio.time_mask(data[i], param=10)],axis=0)
#       7     label.append(label[i])
#       8   return data
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4815         values = ravel(values)
#    4816         axis = arr.ndim-1
# -> 4817     return concatenate((arr, values), axis=axis)
#    4818
#    4819
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
freq_mask = tfio.audio.freq_mask(train_data[1], param=25)
time_mask = tfio.audio.time_mask(freq_mask, param=25)

plt.figure()
plt.imshow(freq_mask.numpy())

plt.figure()
plt.imshow(time_mask.numpy())

# %%
train_data = train_data[:,:,:,np.newaxis]
print(train_data.shape)
val_data = val_data[:,:,:,np.newaxis]
print(val_data.shape)
test_data = test_data[:,:,:,np.newaxis]
print(test_data.shape)
# Out:
# (9896, 128, 94, 1)
# (261, 128, 94, 1)
# (2233, 128, 94, 1)

# %%
CNNmodel = Sequential()
CNNmodel.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(train_data.shape[1],train_data.shape[2],1)))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.MaxPooling2D((2, 2)))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Conv2D(64, (3, 3), activation='relu'))
CNNmodel.add(layers.Flatten())
CNNmodel.add(layers.Dense(64, activation='relu'))
CNNmodel.add(layers.Dropout(0.2))
CNNmodel.add(layers.Dense(32, activation='relu'))
CNNmodel.add(layers.Dense(24, activation='softmax'))
CNNmodel.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),metrics=['accuracy'])
CNNmodel.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 126, 92, 32)       320
#
#  max_pooling2d_19 (MaxPoolin  (None, 63, 46, 32)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 63, 46, 32)        0
#
#  conv2d_24 (Conv2D)          (None, 61, 44, 64)        18496
#
#  max_pooling2d_20 (MaxPoolin  (None, 30, 22, 64)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 30, 22, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 28, 20, 64)        36928
#
#  max_pooling2d_21 (MaxPoolin  (None, 14, 10, 64)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 14, 10, 64)        0
#
#  conv2d_26 (Conv2D)          (None, 12, 8, 64)         36928
#
#  max_pooling2d_22 (MaxPoolin  (None, 6, 4, 64)         0
#  g2D)
#
#  dropout_23 (Dropout)        (None, 6, 4, 64)          0
#
#  conv2d_27 (Conv2D)          (None, 4, 2, 64)          36928
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 64)                32832
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 165,304
# Trainable params: 165,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint("model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=30, verbose=1, mode='auto')
model_history = CNNmodel.fit(np.array(train_data),np.array(train_labels),batch_size=32,epochs=100,validation_data=(np.array(val_data), np.array(val_labels)),callbacks=[checkpoint,early])
CNNmodel = load_model("model.h5")
score, acc = CNNmodel.evaluate(np.array(val_data), np.array(val_labels), verbose=0)
print('Val accuracy:', acc)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.9486 - accuracy: 0.1704
# Epoch 1: val_accuracy improved from -inf to 0.16858, saving model to model.h5
# 310/310 [==============================] - 6s 16ms/step - loss: 1.9482 - accuracy: 0.1703 - val_loss: 2.1755 - val_accuracy: 0.1686
# Epoch 2/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.7474 - accuracy: 0.2362
# Epoch 2: val_accuracy improved from 0.16858 to 0.33716, saving model to model.h5
# 310/310 [==============================] - 5s 16ms/step - loss: 1.7464 - accuracy: 0.2366 - val_loss: 1.6655 - val_accuracy: 0.3372
# Epoch 3/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.5880 - accuracy: 0.3466
# Epoch 3: val_accuracy did not improve from 0.33716
# 310/310 [==============================] - 4s 14ms/step - loss: 1.5878 - accuracy: 0.3465 - val_loss: 1.5702 - val_accuracy: 0.3333
# Epoch 4/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.5014 - accuracy: 0.3921
# Epoch 4: val_accuracy improved from 0.33716 to 0.44828, saving model to model.h5
# 310/310 [==============================] - 5s 15ms/step - loss: 1.5013 - accuracy: 0.3922 - val_loss: 1.4763 - val_accuracy: 0.4483
# Epoch 5/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.4550 - accuracy: 0.4141
# Epoch 5: val_accuracy improved from 0.44828 to 0.46360, saving model to model.h5
# 310/310 [==============================] - 5s 15ms/step - loss: 1.4552 - accuracy: 0.4139 - val_loss: 1.4275 - val_accuracy: 0.4636
# Epoch 6/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.4287 - accuracy: 0.4286
# Epoch 6: val_accuracy did not improve from 0.46360
# 310/310 [==============================] - 4s 14ms/step - loss: 1.4287 - accuracy: 0.4287 - val_loss: 1.4328 - val_accuracy: 0.4483
# Epoch 7/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.3666 - accuracy: 0.4562
# Epoch 7: val_accuracy improved from 0.46360 to 0.47126, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 1.3663 - accuracy: 0.4563 - val_loss: 1.3518 - val_accuracy: 0.4713
# Epoch 8/100
# 307/310 [============================>.] - ETA: 0s - loss: 1.3326 - accuracy: 0.4709
# Epoch 8: val_accuracy did not improve from 0.47126
# 310/310 [==============================] - 4s 14ms/step - loss: 1.3328 - accuracy: 0.4709 - val_loss: 1.3339 - val_accuracy: 0.4636
# Epoch 9/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.2913 - accuracy: 0.4947
# Epoch 9: val_accuracy improved from 0.47126 to 0.47510, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 1.2915 - accuracy: 0.4946 - val_loss: 1.2896 - val_accuracy: 0.4751
# Epoch 10/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.2590 - accuracy: 0.5083
# Epoch 10: val_accuracy improved from 0.47510 to 0.48276, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 1.2590 - accuracy: 0.5082 - val_loss: 1.2530 - val_accuracy: 0.4828
# Epoch 11/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.2194 - accuracy: 0.5245
# Epoch 11: val_accuracy improved from 0.48276 to 0.48659, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 1.2188 - accuracy: 0.5247 - val_loss: 1.2601 - val_accuracy: 0.4866
# Epoch 12/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.1875 - accuracy: 0.5441
# Epoch 12: val_accuracy did not improve from 0.48659
# 310/310 [==============================] - 5s 17ms/step - loss: 1.1873 - accuracy: 0.5443 - val_loss: 1.3269 - val_accuracy: 0.4559
# Epoch 13/100
# 307/310 [============================>.] - ETA: 0s - loss: 1.1596 - accuracy: 0.5506
# Epoch 13: val_accuracy improved from 0.48659 to 0.51341, saving model to model.h5
# 310/310 [==============================] - 5s 15ms/step - loss: 1.1602 - accuracy: 0.5503 - val_loss: 1.3095 - val_accuracy: 0.5134
# Epoch 14/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.1290 - accuracy: 0.5675
# Epoch 14: val_accuracy did not improve from 0.51341
# 310/310 [==============================] - 4s 14ms/step - loss: 1.1290 - accuracy: 0.5674 - val_loss: 1.2226 - val_accuracy: 0.4943
# Epoch 15/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.1142 - accuracy: 0.5659
# Epoch 15: val_accuracy did not improve from 0.51341
# 310/310 [==============================] - 4s 14ms/step - loss: 1.1143 - accuracy: 0.5660 - val_loss: 1.2227 - val_accuracy: 0.4866
# Epoch 16/100
# 308/310 [============================>.] - ETA: 0s - loss: 1.0911 - accuracy: 0.5777
# Epoch 16: val_accuracy did not improve from 0.51341
# 310/310 [==============================] - 4s 14ms/step - loss: 1.0906 - accuracy: 0.5776 - val_loss: 1.3053 - val_accuracy: 0.4674
# Epoch 17/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.0696 - accuracy: 0.5940
# Epoch 17: val_accuracy improved from 0.51341 to 0.54023, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 1.0699 - accuracy: 0.5938 - val_loss: 1.1882 - val_accuracy: 0.5402
# Epoch 18/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.0485 - accuracy: 0.5995
# Epoch 18: val_accuracy did not improve from 0.54023
# 310/310 [==============================] - 4s 14ms/step - loss: 1.0483 - accuracy: 0.5996 - val_loss: 1.2136 - val_accuracy: 0.4866
# Epoch 19/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.0249 - accuracy: 0.6061
# Epoch 19: val_accuracy improved from 0.54023 to 0.56705, saving model to model.h5
# 310/310 [==============================] - 5s 15ms/step - loss: 1.0249 - accuracy: 0.6061 - val_loss: 1.1334 - val_accuracy: 0.5670
# Epoch 20/100
# 309/310 [============================>.] - ETA: 0s - loss: 1.0028 - accuracy: 0.6184
# Epoch 20: val_accuracy did not improve from 0.56705
# 310/310 [==============================] - 4s 14ms/step - loss: 1.0025 - accuracy: 0.6185 - val_loss: 1.2011 - val_accuracy: 0.5287
# Epoch 21/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.9627 - accuracy: 0.6322
# Epoch 21: val_accuracy improved from 0.56705 to 0.59004, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 0.9627 - accuracy: 0.6323 - val_loss: 1.1292 - val_accuracy: 0.5900
# Epoch 22/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.9619 - accuracy: 0.6365
# Epoch 22: val_accuracy did not improve from 0.59004
# 310/310 [==============================] - 4s 14ms/step - loss: 0.9618 - accuracy: 0.6365 - val_loss: 1.1489 - val_accuracy: 0.5632
# Epoch 23/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.9259 - accuracy: 0.6464
# Epoch 23: val_accuracy did not improve from 0.59004
# 310/310 [==============================] - 4s 14ms/step - loss: 0.9260 - accuracy: 0.6464 - val_loss: 1.1476 - val_accuracy: 0.5709
# Epoch 24/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.9133 - accuracy: 0.6544
# Epoch 24: val_accuracy did not improve from 0.59004
# 310/310 [==============================] - 4s 14ms/step - loss: 0.9134 - accuracy: 0.6544 - val_loss: 1.2098 - val_accuracy: 0.5326
# Epoch 25/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.8998 - accuracy: 0.6618
# Epoch 25: val_accuracy did not improve from 0.59004
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8996 - accuracy: 0.6619 - val_loss: 1.2557 - val_accuracy: 0.5632
# Epoch 26/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.8797 - accuracy: 0.6704
# Epoch 26: val_accuracy did not improve from 0.59004
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8796 - accuracy: 0.6702 - val_loss: 1.1139 - val_accuracy: 0.5785
# Epoch 27/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.8645 - accuracy: 0.6722
# Epoch 27: val_accuracy improved from 0.59004 to 0.60153, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8645 - accuracy: 0.6722 - val_loss: 1.1348 - val_accuracy: 0.6015
# Epoch 28/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.8493 - accuracy: 0.6765
# Epoch 28: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8491 - accuracy: 0.6765 - val_loss: 1.1622 - val_accuracy: 0.5670
# Epoch 29/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.8148 - accuracy: 0.6939
# Epoch 29: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8153 - accuracy: 0.6936 - val_loss: 1.1201 - val_accuracy: 0.5632
# Epoch 30/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.8238 - accuracy: 0.6858
# Epoch 30: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.8237 - accuracy: 0.6858 - val_loss: 1.2646 - val_accuracy: 0.5632
# Epoch 31/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.7982 - accuracy: 0.6966
# Epoch 31: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7980 - accuracy: 0.6967 - val_loss: 1.1509 - val_accuracy: 0.5977
# Epoch 32/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.7874 - accuracy: 0.7021
# Epoch 32: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7874 - accuracy: 0.7022 - val_loss: 1.2529 - val_accuracy: 0.5326
# Epoch 33/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.7745 - accuracy: 0.7081
# Epoch 33: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7754 - accuracy: 0.7079 - val_loss: 1.1522 - val_accuracy: 0.5900
# Epoch 34/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.7445 - accuracy: 0.7174
# Epoch 34: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7446 - accuracy: 0.7174 - val_loss: 1.2124 - val_accuracy: 0.5785
# Epoch 35/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.7302 - accuracy: 0.7291
# Epoch 35: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7302 - accuracy: 0.7291 - val_loss: 1.1772 - val_accuracy: 0.5939
# Epoch 36/100
# 306/310 [============================>.] - ETA: 0s - loss: 0.7584 - accuracy: 0.7134
# Epoch 36: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 5s 15ms/step - loss: 0.7566 - accuracy: 0.7141 - val_loss: 1.1807 - val_accuracy: 0.5977
# Epoch 37/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.7394 - accuracy: 0.7179
# Epoch 37: val_accuracy did not improve from 0.60153
# 310/310 [==============================] - 4s 14ms/step - loss: 0.7397 - accuracy: 0.7179 - val_loss: 1.1351 - val_accuracy: 0.5824
# Epoch 38/100
# 307/310 [============================>.] - ETA: 0s - loss: 0.7183 - accuracy: 0.7329
# Epoch 38: val_accuracy improved from 0.60153 to 0.60920, saving model to model.h5
# 310/310 [==============================] - 5s 15ms/step - loss: 0.7191 - accuracy: 0.7329 - val_loss: 1.1820 - val_accuracy: 0.6092
# Epoch 39/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6900 - accuracy: 0.7397
# Epoch 39: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6897 - accuracy: 0.7398 - val_loss: 1.2030 - val_accuracy: 0.5709
# Epoch 40/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6860 - accuracy: 0.7398
# Epoch 40: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6864 - accuracy: 0.7396 - val_loss: 1.1736 - val_accuracy: 0.5785
# Epoch 41/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6747 - accuracy: 0.7489
# Epoch 41: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6748 - accuracy: 0.7488 - val_loss: 1.2126 - val_accuracy: 0.5939
# Epoch 42/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.7509
# Epoch 42: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6699 - accuracy: 0.7511 - val_loss: 1.2222 - val_accuracy: 0.5479
# Epoch 43/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6498 - accuracy: 0.7556
# Epoch 43: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6498 - accuracy: 0.7557 - val_loss: 1.1553 - val_accuracy: 0.5709
# Epoch 44/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.6444 - accuracy: 0.7580
# Epoch 44: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6442 - accuracy: 0.7581 - val_loss: 1.1033 - val_accuracy: 0.6054
# Epoch 45/100
# 307/310 [============================>.] - ETA: 0s - loss: 0.6486 - accuracy: 0.7554
# Epoch 45: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 5s 15ms/step - loss: 0.6491 - accuracy: 0.7550 - val_loss: 1.2080 - val_accuracy: 0.5556
# Epoch 46/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6380 - accuracy: 0.7604
# Epoch 46: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6381 - accuracy: 0.7603 - val_loss: 1.1935 - val_accuracy: 0.5977
# Epoch 47/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.7695
# Epoch 47: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6295 - accuracy: 0.7697 - val_loss: 1.2585 - val_accuracy: 0.5441
# Epoch 48/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6196 - accuracy: 0.7693
# Epoch 48: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6196 - accuracy: 0.7692 - val_loss: 1.2344 - val_accuracy: 0.5900
# Epoch 49/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.6208 - accuracy: 0.7703
# Epoch 49: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6214 - accuracy: 0.7702 - val_loss: 1.1876 - val_accuracy: 0.5900
# Epoch 50/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5866 - accuracy: 0.7800
# Epoch 50: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5867 - accuracy: 0.7800 - val_loss: 1.2351 - val_accuracy: 0.5824
# Epoch 51/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.6102 - accuracy: 0.7783
# Epoch 51: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.6099 - accuracy: 0.7785 - val_loss: 1.2187 - val_accuracy: 0.5977
# Epoch 52/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5836 - accuracy: 0.7816
# Epoch 52: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5838 - accuracy: 0.7815 - val_loss: 1.3318 - val_accuracy: 0.5556
# Epoch 53/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5664 - accuracy: 0.7903
# Epoch 53: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5666 - accuracy: 0.7902 - val_loss: 1.2324 - val_accuracy: 0.5326
# Epoch 54/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.5544 - accuracy: 0.7892
# Epoch 54: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5550 - accuracy: 0.7888 - val_loss: 1.2057 - val_accuracy: 0.5517
# Epoch 55/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.5582 - accuracy: 0.7915
# Epoch 55: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5589 - accuracy: 0.7911 - val_loss: 1.2107 - val_accuracy: 0.5747
# Epoch 56/100
# 307/310 [============================>.] - ETA: 0s - loss: 0.5572 - accuracy: 0.7951
# Epoch 56: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5573 - accuracy: 0.7950 - val_loss: 1.2737 - val_accuracy: 0.5632
# Epoch 57/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5389 - accuracy: 0.7987
# Epoch 57: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5388 - accuracy: 0.7988 - val_loss: 1.2518 - val_accuracy: 0.5441
# Epoch 58/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5476 - accuracy: 0.7922
# Epoch 58: val_accuracy did not improve from 0.60920
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5478 - accuracy: 0.7921 - val_loss: 1.1888 - val_accuracy: 0.5900
# Epoch 59/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5128 - accuracy: 0.8121
# Epoch 59: val_accuracy improved from 0.60920 to 0.61686, saving model to model.h5
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5126 - accuracy: 0.8121 - val_loss: 1.2097 - val_accuracy: 0.6169
# Epoch 60/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5263 - accuracy: 0.8062
# Epoch 60: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.5261 - accuracy: 0.8064 - val_loss: 1.2899 - val_accuracy: 0.5517
# Epoch 61/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5203 - accuracy: 0.8054
# Epoch 61: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5205 - accuracy: 0.8053 - val_loss: 1.2348 - val_accuracy: 0.5594
# Epoch 62/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5312 - accuracy: 0.8072
# Epoch 62: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5318 - accuracy: 0.8072 - val_loss: 1.2066 - val_accuracy: 0.5862
# Epoch 63/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5100 - accuracy: 0.8161
# Epoch 63: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5102 - accuracy: 0.8161 - val_loss: 1.2597 - val_accuracy: 0.5824
# Epoch 64/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.5100 - accuracy: 0.8152
# Epoch 64: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.5098 - accuracy: 0.8153 - val_loss: 1.2123 - val_accuracy: 0.5785
# Epoch 65/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.8227
# Epoch 65: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4942 - accuracy: 0.8229 - val_loss: 1.1706 - val_accuracy: 0.6130
# Epoch 66/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4894 - accuracy: 0.8209
# Epoch 66: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4894 - accuracy: 0.8209 - val_loss: 1.3182 - val_accuracy: 0.5747
# Epoch 67/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4867 - accuracy: 0.8180
# Epoch 67: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4862 - accuracy: 0.8182 - val_loss: 1.2928 - val_accuracy: 0.5364
# Epoch 68/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4777 - accuracy: 0.8235
# Epoch 68: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 15ms/step - loss: 0.4769 - accuracy: 0.8240 - val_loss: 1.2787 - val_accuracy: 0.5824
# Epoch 69/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4754 - accuracy: 0.8257
# Epoch 69: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4751 - accuracy: 0.8258 - val_loss: 1.2848 - val_accuracy: 0.6054
# Epoch 70/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4558 - accuracy: 0.8357
# Epoch 70: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4557 - accuracy: 0.8358 - val_loss: 1.3094 - val_accuracy: 0.5824
# Epoch 71/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4586 - accuracy: 0.8338
# Epoch 71: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4590 - accuracy: 0.8336 - val_loss: 1.2536 - val_accuracy: 0.5939
# Epoch 72/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4756 - accuracy: 0.8316
# Epoch 72: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4755 - accuracy: 0.8316 - val_loss: 1.4049 - val_accuracy: 0.5709
# Epoch 73/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4657 - accuracy: 0.8316
# Epoch 73: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4655 - accuracy: 0.8318 - val_loss: 1.3335 - val_accuracy: 0.5670
# Epoch 74/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4524 - accuracy: 0.8355
# Epoch 74: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4522 - accuracy: 0.8355 - val_loss: 1.3781 - val_accuracy: 0.5441
# Epoch 75/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4402 - accuracy: 0.8425
# Epoch 75: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4407 - accuracy: 0.8424 - val_loss: 1.3820 - val_accuracy: 0.5670
# Epoch 76/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4603 - accuracy: 0.8313
# Epoch 76: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4599 - accuracy: 0.8316 - val_loss: 1.3538 - val_accuracy: 0.5977
# Epoch 77/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.8375
# Epoch 77: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4499 - accuracy: 0.8375 - val_loss: 1.4443 - val_accuracy: 0.5632
# Epoch 78/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4364 - accuracy: 0.8441
# Epoch 78: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 15ms/step - loss: 0.4361 - accuracy: 0.8442 - val_loss: 1.3719 - val_accuracy: 0.5709
# Epoch 79/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4322 - accuracy: 0.8419
# Epoch 79: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4318 - accuracy: 0.8421 - val_loss: 1.3552 - val_accuracy: 0.5862
# Epoch 80/100
# 306/310 [============================>.] - ETA: 0s - loss: 0.4321 - accuracy: 0.8444
# Epoch 80: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4320 - accuracy: 0.8446 - val_loss: 1.3297 - val_accuracy: 0.5441
# Epoch 81/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4346 - accuracy: 0.8402
# Epoch 81: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4341 - accuracy: 0.8404 - val_loss: 1.3545 - val_accuracy: 0.5709
# Epoch 82/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4124 - accuracy: 0.8458
# Epoch 82: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4123 - accuracy: 0.8459 - val_loss: 1.3337 - val_accuracy: 0.5594
# Epoch 83/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4214 - accuracy: 0.8458
# Epoch 83: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4213 - accuracy: 0.8458 - val_loss: 1.3237 - val_accuracy: 0.5402
# Epoch 84/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4063 - accuracy: 0.8579
# Epoch 84: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4065 - accuracy: 0.8579 - val_loss: 1.3293 - val_accuracy: 0.5594
# Epoch 85/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.4087 - accuracy: 0.8551
# Epoch 85: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.4093 - accuracy: 0.8549 - val_loss: 1.3207 - val_accuracy: 0.5785
# Epoch 86/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4067 - accuracy: 0.8564
# Epoch 86: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 5s 15ms/step - loss: 0.4062 - accuracy: 0.8566 - val_loss: 1.3316 - val_accuracy: 0.5632
# Epoch 87/100
# 308/310 [============================>.] - ETA: 0s - loss: 0.4132 - accuracy: 0.8525
# Epoch 87: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 15ms/step - loss: 0.4131 - accuracy: 0.8521 - val_loss: 1.2839 - val_accuracy: 0.5556
# Epoch 88/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.3924 - accuracy: 0.8632
# Epoch 88: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.3925 - accuracy: 0.8632 - val_loss: 1.3399 - val_accuracy: 0.6054
# Epoch 89/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.3944 - accuracy: 0.8592
# Epoch 89: val_accuracy did not improve from 0.61686
# 310/310 [==============================] - 4s 14ms/step - loss: 0.3943 - accuracy: 0.8593 - val_loss: 1.3565 - val_accuracy: 0.5556
# Epoch 89: early stopping
# Val accuracy: 0.6168582439422607

# %%
plt.plot(model_history.history['accuracy'], label='accuracy')
plt.plot(model_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.savefig('Initial_Model_Accuracy.png')
plt.show()
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score, trainacc = CNNmodel.evaluate(np.array(train_data), np.array(train_labels), verbose=0)
y_pred = CNNmodel.predict(test_data)
report=metrics.classification_report(test_labels,np.argmax(y_pred,axis=1)) 
print(report)

matrix = metrics.confusion_matrix(test_labels ,np.argmax(y_pred,axis=1))
sns.heatmap(matrix, annot=True, fmt="d", cmap = 'rocket_r',xticklabels = ['SAD','ANGER','DISGUSTED','FEAR','HAPPY','NEUTRAL'],yticklabels = ['SAD','ANGER','DISGUSTED','FEAR','HAPPY','NEUTRAL'])
print(matrix)

print('val accuracy:', acc*100)
print('train accuracy:', trainacc*100)
print("test accuracy",metrics.accuracy_score(test_labels,np.argmax(y_pred,axis=1))*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.58      0.55       359
#            1       0.72      0.65      0.68       390
#            2       0.53      0.50      0.51       395
#            3       0.61      0.72      0.66       320
#            4       0.55      0.56      0.55       370
#            5       0.54      0.48      0.51       399
#
#     accuracy                           0.58      2233
#    macro avg       0.58      0.58      0.58      2233
# weighted avg       0.58      0.58      0.58      2233
#
# [[208   3  33  46  13  56]
#  [  6 255  43  20  46  20]
#  [ 69  31 198  33  33  31]
#  [ 35   3  23 230  17  12]
#  [ 13  44  35  30 206  42]
#  [ 67  20  44  17  59 192]]
# val accuracy: 61.685824394226074
# train accuracy: 95.3314483165741
# test accuracy 57.725033587102544
